# %% [markdown]
# # WEB SCRAPING

# %%
# !pip install -q snscrape==0.3.4

# %%
import os
import pandas as pd
from datetime import date

# %%
today = date.today()
end_date = today

# %% [markdown]
# # SCRAPPING USING SEARCH TERM

# %%
search_term = 'bully'
from_date = '2019-01-01'

# %%
max_results = 100

# %%
extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > search_term.csv"
os.system(extracted_tweets)
if os.stat("search_term.csv").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('search_term.csv', names=['content'])

# %%
df
# Out:
#                                                                                               content
# 'I hate bullying. I have been bullied and I hav...   but at least my sensitivity allows me to be c...
# '@fwe1991 @JDS44894884 @ShellyRKirchoff @Huckle...   I hated bullies. I always made a point to get...
# 'if my boyfriend ever posts something like this...   I am BEGGING y’all to bully me please 😭 https...
# 'busko amigitas neveritas q no ulteen a miyeon ...                                                NaN
# 'Sooo would you eat Arbys or Long John silvers'                                                   NaN
# ...                                                                                               ...
# 'Daniel to Terrance- He (Turner) did say "the b...                                                NaN
# i don't like bullies😡                                                                             NaN
# ...

# %% [markdown]
# # SCRAPPING USING PUBLIC ACCOUNT

# %%
user_name = "BarackObama"
user_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-user '{user_name} until:{end_date}' > user-tweets.csv"
os.system(user_tweets)
if os.stat("user-tweets.csv").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('user-tweets.csv', names=['content'])

# %%
df
# Out:
#                                                                                                                                                                                                                                       content
# 'There is so much power in telling our story        sharing our truth                                  and inviting others into our lives. I’m so pro...  The Light We Carry                 and can’t wait for you to read it. https://t....
# 'Ahead of Mandela Day                               I spoke with the talented young people who jus...  and are working together to find solutions. I ... NaN                                                                              NaN
# 'John Lewis and Reverend C.T. Vivian dedicated ...  and now it’s up to all of us to follow in thei... NaN                                                NaN                                                                              NaN
# ...
